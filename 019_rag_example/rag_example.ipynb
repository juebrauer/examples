# %% [markdown]
# # Alle benötigten Python-Pakete installieren

# %%
# !pip install langchain langchain_community
# !pip install pypdf
# !pip install langchain_openai
# !pip install chromadb
# Out:
# Requirement already satisfied: langchain in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (1.2.7)
# Requirement already satisfied: langchain_community in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.7 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain) (1.2.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.7 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain) (1.0.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.7->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (0.25.0)
# Requirement already satisfied: anyio in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (4.9.0)
# Requirement already satisfied: certifi in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (1.0.9)
# Requirement already satisfied: idna in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain_community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain_community) (2.0.46)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain_community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (1.3.1)
# Requirement already satisfied: pypdf in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (6.6.0)
# Requirement already satisfied: langchain_openai in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (1.1.7)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.6 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain_openai) (1.2.7)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain_openai) (1.109.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.6->langchain_openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.25.0)
# Requirement already satisfied: anyio in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (4.9.0)
# Requirement already satisfied: certifi in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (1.0.9)
# Requirement already satisfied: idna in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.11.1)
# Requirement already satisfied: sniffio in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.6->langchain_openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (2.5.0)
# Requirement already satisfied: chromadb in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (1.4.1)
# Requirement already satisfied: build>=1.0.3 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pydantic>=1.9 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (2.12.3)
# Requirement already satisfied: pybase64>=1.4.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.40.0)
# Requirement already satisfied: numpy>=1.22.5 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (4.14.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (1.23.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (0.50.0)
# Requirement already satisfied: tqdm>=4.65.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from chromadb) (4.25.0)
# Requirement already satisfied: requests<3.0,>=2.7 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.7.14)
# Requirement already satisfied: packaging>=24.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: anyio in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.26.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.0)
# Requirement already satisfied: sympy in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: filelock in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: click>=8.0.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/juebrauer/miniconda3/envs/env_teaching/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %% [markdown]
# # Dokumente zusammenstellen

# %%
URL = "https://www.uni-hannover.de/fileadmin/luh/studium/ordnungen/stpo/f_inform_bpo24.pdf"
import urllib.request
urllib.request.urlretrieve(URL, "dokument1.pdf")
# Out:
# ('dokument1.pdf', <http.client.HTTPMessage at 0x7619e0580980>)

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("dokument1.pdf")
pages = loader.load()

# %%
len(pages)
# Out:
# 34

# %%
type(pages)
# Out:
# list

# %%
pages[0].page_content
# Out:
# 'Verkündungsblatt der Gottfried Wilhelm Leibniz Universität Hannover vom 24.09.2024 13/2024 \nSeite 56 \nDer Dekan der Fakultät für Elektrotechnik und Informatik der Gottfried Wilhelm Leibniz Universität Hannover hat am \n17.07.2024 per Eilbeschluss die nachstehende Änderung der Prüfungsordnung für den Bachelorstudiengang Informatik \nvom 23.03.2017, in der Fassung der letzten Änderung beschlossen. Das Präsidium hat die Änderung am 28.08.2024 \ngemäß § 37 Abs. 1 Nr. 5. b) des Niedersächsischen Hochschulgesetzes genehmigt. Sie tritt nach ihrer hochschulöffentli-\nchen Bekanntmachung im Verkündungsblatt der Gottfried Wilhelm Leibniz Universität Hannover zum 01.10.2024 in \nKraft. \n \nÄnderung der Prüfungsordnung für den Bachelorstudiengang Informatik \nan der Gottfried Wilhelm Leibniz Universität Hannover vom 23.03.2017,  \nmit Änderungen vom 18.09.2018, 13.08.2019, 01.09.2020, 30.07.2021, 08.09.2022 (berichtigt am \n07.11.2022) und 24.04.2024 (berichtigt am 22.05.2024) \n \nDie\n Fakultät für Elektrotechnik und Informatik der Gottfried Wilhelm Leibniz Universität Hannover hat gemäß §§ \n7 Absatz 3, 44 Absatz 1 des Niedersächsischen Hochschulgesetzes die folgende, geänderte Prüfungsord-\nnung erlassen: \nÜbersicht \n \nErster Teil: Allgemeines  \n§ 1 Zweck der Prüfung und Hochschulgrad \n§ 2 Dauer und Gliederung des Studiums, Zwischenprüfung \n§ 3 Zuständigkeit (Studiendekanin oder  Studiendekan, Prüfungsausschuss) \n \nZweiter Teil: Bachelorprüfung \n§ 4 Aufbau und Inhalt der Prüfung \n§ 5 Prüferinnen und Prüfer sowie Beisitzende \n§ 6 Studien- und Prüfungsleistungen \n§ 6a  Digitale Prüfungsformate \n§ 7 Bachelorarbeit  \n§ 8 Bestehen und Nichtbestehen  \n§ 9 Zusätzliche Module und Prüfungen \n§ 10 Anerkennung bereits erbrachter Studien- und Prüfungsleistungen \n§ 10a Einstufungsprüfung für Geflüchtete \n§ 11 Erbringung von Prüfungsleistungen durch Juniorstudierende  \n \nDritter Teil: Prüfungsverfahren \n§ 12 Zulassung zu Prüfungsleistungen \n§ 13 Anmeldung \n§ 14 Wiederholung \n§ 15 Versäumnis, Rückt ritt, Fristverlängerung \n§ 16 Prüfungsmodalitäten in Härtefällen \n§ 17 Bewertung von Prüfungsleistungen \n§ 18 Täuschung, Ordnungsverstoß \n§ 19 Leistungspunkte und Module \n§ 20 Gesamtnotenbildung \n§ 21 Zeugnisse und Bescheinigungen \n§ 22 Einsicht in die Prüfungsakten \n§ 23 Verfahrensvorschriften  \n \nVierter Teil: Schlussvorschriften \n§ 24 Inkrafttreten und Übergangsbestimmung'

# %%
type( pages[0].page_content )
# Out:
# str

# %% [markdown]
# # Dokumente in Stücke zerschneiden

# %%
text_len = len(pages[0].page_content)
text_len
# Out:
# 2374

# %%
pages[0].page_content[text_len//2:]
# Out:
# '\nnung erlassen: \nÜbersicht \n \nErster Teil: Allgemeines  \n§ 1 Zweck der Prüfung und Hochschulgrad \n§ 2 Dauer und Gliederung des Studiums, Zwischenprüfung \n§ 3 Zuständigkeit (Studiendekanin oder  Studiendekan, Prüfungsausschuss) \n \nZweiter Teil: Bachelorprüfung \n§ 4 Aufbau und Inhalt der Prüfung \n§ 5 Prüferinnen und Prüfer sowie Beisitzende \n§ 6 Studien- und Prüfungsleistungen \n§ 6a  Digitale Prüfungsformate \n§ 7 Bachelorarbeit  \n§ 8 Bestehen und Nichtbestehen  \n§ 9 Zusätzliche Module und Prüfungen \n§ 10 Anerkennung bereits erbrachter Studien- und Prüfungsleistungen \n§ 10a Einstufungsprüfung für Geflüchtete \n§ 11 Erbringung von Prüfungsleistungen durch Juniorstudierende  \n \nDritter Teil: Prüfungsverfahren \n§ 12 Zulassung zu Prüfungsleistungen \n§ 13 Anmeldung \n§ 14 Wiederholung \n§ 15 Versäumnis, Rückt ritt, Fristverlängerung \n§ 16 Prüfungsmodalitäten in Härtefällen \n§ 17 Bewertung von Prüfungsleistungen \n§ 18 Täuschung, Ordnungsverstoß \n§ 19 Leistungspunkte und Module \n§ 20 Gesamtnotenbildung \n§ 21 Zeugnisse und Bescheinigungen \n§ 22 Einsicht in die Prüfungsakten \n§ 23 Verfahrensvorschriften  \n \nVierter Teil: Schlussvorschriften \n§ 24 Inkrafttreten und Übergangsbestimmung'

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
chunks = splitter.split_documents( pages )

# %%
type(chunks)
# Out:
# list

# %%
len(chunks)
# Out:
# 226

# %%
chunks[0].page_content
# Out:
# 'Verkündungsblatt der Gottfried Wilhelm Leibniz Universität Hannover vom 24.09.2024 13/2024 \nSeite 56 \nDer Dekan der Fakultät für Elektrotechnik und Informatik der Gottfried Wilhelm Leibniz Universität Hannover hat am \n17.07.2024 per Eilbeschluss die nachstehende Änderung der Prüfungsordnung für den Bachelorstudiengang Informatik \nvom 23.03.2017, in der Fassung der letzten Änderung beschlossen. Das Präsidium hat die Änderung am 28.08.2024'

# %% [markdown]
# # Vektordatenbank erstellen

# %%
# 1. Dokument(e) bereitstellen
URL = "https://www.uni-hannover.de/fileadmin/luh/studium/ordnungen/stpo/f_inform_bpo24.pdf"
import urllib.request
urllib.request.urlretrieve(URL, "dokument1.pdf")

# 2. Dokument(e) einlesen
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("dokument1.pdf")
pages = loader.load()

# 3. Dokument(e) zerstückeln in "Chunks"
from langchain_text_splitters import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
chunks = splitter.split_documents( pages )

# 4. ChomaDB erstellen
api_key = "<insert your OpenAI API key here>"
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
embeddings = OpenAIEmbeddings(api_key=api_key)
vectorstore = Chroma.from_documents(
    chunks,
    embedding=embeddings,
    persist_directory="chromadb_studienordnungen"
)

# %% [markdown]
# # Beispielabfrage (Retrieval)

# %%
prompt = "Wieviele Personen sind in der Prüfungskommission?"

docs = vectorstore.similarity_search(prompt, k=5)

# %%
type(docs)
# Out:
# list

# %%
len(docs)
# Out:
# 5

# %%
docs[0]
# Out:
# Document(metadata={'source': 'dokument1.pdf', 'page': 1, 'page_label': '2', 'keywords': 'Änderung der Prüfungsordnung für den Bachelorstudiengang Informatik an der Gottfried Wilhelm Leibniz Universität Hannover vom 23.03.2017, mit Änderungen vom 18.09.2018, 13.08.2019, 01.09.2020, 30.07.2021, 08.09.2022 (berichtigt am 07.11.2022) und 24.04.2024 (berichtigt am 22.05.2024) Verkündungsblatt Nr. 13/2024', 'total_pages': 34, 'subject': 'Änderung der Prüfungsordnung für den Bachelorstudiengang Informatik an der Gottfried Wilhelm Leibniz Universität Hannover vom 23.03.2017, mit Änderungen vom 18.09.2018, 13.08.2019, 01.09.2020, 30.07.2021, 08.09.2022 (berichtigt am 07.11.2022) und 24.04.2024 (berichtigt am 22.05.2024) Verkündungsblatt Nr. 13/2024', 'title': 'Änderung der Prüfungsordnung für den Bachelorstudiengang Informatik an der Gottfried Wilhelm Leibniz Universität Hannover vom 23.03.2017, mit Änderungen vom 18.09.2018, 13.08.2019, 01.09.2020, 30.07.2021, 08.09.2022 (berichtigt am 07.11.2022) und 24.04.2024 (berichtigt am 22.05.2024) Verkündungsblatt Nr. 13/2024', 'moddate': '2024-09-26T13:17:31+02:00', 'creationdate': '2024-09-26T13:09:58+02:00', 'author': 'Leibniz Universität Hannover', 'creator': 'PScript5.dll Version 5.2.2', 'producer': 'Acrobat Distiller 24.0 (Windows)'}, page_content='gung dieser Aufgaben eingesetzt wird. \n(2) \n1Dem Prüfungsausschuss gehören fünf Mitglieder an, und zwar drei Mitglieder aus der Hochschullehrer-\ngruppe, ein Mitglied, das die Mitarbeitergruppe vertritt und in der Lehre tätig ist, sowie ein Mitglied der \nStudierendengruppe. 2Die Mitglieder des Prüfungsausschusses sowie deren Vertretungen werden durch \ndie jeweiligen Gruppenvertretungen benannt. 3Der Vorsitz und der stellvertretende Vorsitz, über die der')

# %% [markdown]
# # Augmentierten Prompt erstellen

# %%
prompt
# Out:
# 'Wieviele Personen sind in der Prüfungskommission?'

# %%
docs[0].page_content
# Out:
# 'gung dieser Aufgaben eingesetzt wird. \n(2) \n1Dem Prüfungsausschuss gehören fünf Mitglieder an, und zwar drei Mitglieder aus der Hochschullehrer-\ngruppe, ein Mitglied, das die Mitarbeitergruppe vertritt und in der Lehre tätig ist, sowie ein Mitglied der \nStudierendengruppe. 2Die Mitglieder des Prüfungsausschusses sowie deren Vertretungen werden durch \ndie jeweiligen Gruppenvertretungen benannt. 3Der Vorsitz und der stellvertretende Vorsitz, über die der'

# %%
kontext_infos = ""
for doc in docs:
    kontext_infos += "\n----\n" + doc.page_content + "\n"

prompt_aug = f"""Beantworte die folgende Frage nur auf Basis der im Kontext 
von RAG extrahierten Chunks:
----
{prompt}
----
Chunks:
{kontext_infos}
"""

print(prompt_aug)
# Out:
# Beantworte die folgende Frage nur auf Basis der im Kontext
# von RAG extrahierten Chunks:
# ----
# Wieviele Personen sind in der Prüfungskommission?
# ----
# Chunks:
#
# ----
# gung dieser Aufgaben eingesetzt wird.
# (2)
# 1Dem Prüfungsausschuss gehören fünf Mitglieder an, und zwar drei Mitglieder aus der Hochschullehrer-
# gruppe, ein Mitglied, das die Mitarbeitergruppe vertritt und in der Lehre tätig ist, sowie ein Mitglied der
# Studierendengruppe. 2Die Mitglieder des Prüfungsausschusses sowie deren Vertretungen werden durch
# die jeweiligen Gruppenvertretungen benannt. 3Der Vorsitz und der stellvertretende Vorsitz, über die der
#
# ----
# Prüfungsausschuss entscheidet, müssen von Mitgliedern der Hochschullehrergruppe oder habilitierten
# Mitgliedern ausgeübt werden. 4Das studentische Mitglied hat in Bewertungsfragen und bei der Entschei-
# dung über die Anerkennung von Prüfungsleistungen nur beratende Stimme. 5Die Studiendekanin oder
# der Studiendekan kann, falls sie oder er nicht als Mitglied des Prüfungsausschusses benannt wird, an
# den Sitzungen des Prüfungsausschusses mit beratender Stimme teilnehmen.
#
# ----
# gen Beisitzenden als Einzelprüfung statt. 4Wesentliche Gegenstände der Prüfungsleistung werden in
# einem Protokoll festgehalten. 5Studierende, die sich an einem späteren Prüfungstermin der gleichen
# Prüfung unterziehen wollen, sowie andere Mitglieder der Hochschule, die ein eigenes berechtigtes
# Interesse geltend machen, sind als Zuhörende bei Künstlerisch-Wissenschaftlichen Präsentationen
# zuzulassen. 6Dies erstreckt sich nicht auf die Beratung und Bekanntgabe des Prüfungsergebnisses
#
# ----
# § 5  Prüferinnen und Prüfer sowie Beisitzende
# 1Das nach § 3 zuständige Organ bestellt für die Module des Studiengangs Informatik Mitglieder der Hoch-
# schullehrergruppe der Fakultät für Elektrotechnik und Informatik der Gottfried Wilhelm Leibniz Universität
# Hannover als Prüfungsberechtigte sowie die Beisitzenden. 2Das nach § 3 zuständige Organ kann weitere
# Prüfende bestellen, sofern diese mindestens die durch die Prüfung festzustellende oder eine gleichwertige
#
# ----
# (3) 1Die Mitglieder des Prüfungsausschusses und deren Vertretungen unterliegen der Amtsverschwiegen-
# heit. 2Sofern sie nicht im öffentlichen Dienst stehen, sind sie durch die Vorsitzende oder den Vorsitzen-
# den zur Verschwiegenheit zu verpflichten.
# (4) 1Der Prüfungsausschuss ist beschlussfähig, soweit die Mehrheit der stimmberechtigten Mitglieder anwe-
# send ist. 2Beschlüsse werden mit der Mehrheit der abgegebenen gültigen Stimmen gefasst; Stimmenthal-

# %% [markdown]
# # RAG in einem Skript (wenn Vector Datenbank schon da)

# %%
# 1. Was will der Anfragende wissen?
prompt = "Wieviele Personen sind in der Prüfungskommission?"

# 2. Vektordatenbank wiederherstellen
api_key = "<insert your OpenAI API key here>"
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
embeddings = OpenAIEmbeddings(api_key=api_key)
vectorstore = Chroma(embedding_function=embeddings,
                     persist_directory="chromadb_studienordnungen"
                    )

# 3. Chunk Retrieval
docs = vectorstore.similarity_search(prompt, k=5)

# 4. Erstelle augmentierten Prompt
kontext_infos = ""
for doc in docs:
    kontext_infos += "\n----\n" + doc.page_content + "\n"
prompt_aug = f"""Beantworte die folgende Frage NUR auf Basis der im Kontext 
von RAG extrahierten Chunks:
----
{prompt}
----
Chunks:
{kontext_infos}
"""
print(prompt_aug)

# 5. Augmentierten Prompt an ein LLM stellen
from openai import OpenAI
client = OpenAI(api_key=api_key)
response = client.responses.create(
    model="gpt-5.2",
    input=prompt_aug,
    temperature=0.0
)
print("\n\n")
print("ANTWORT DES MODELLS:")
print("-" * 50)
print(response.output_text)
# Out:
# /tmp/ipykernel_20530/2346370852.py:9: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   vectorstore = Chroma(embedding_function=embeddings,
# Beantworte die folgende Frage NUR auf Basis der im Kontext
# von RAG extrahierten Chunks:
# ----
# Wieviele Personen sind in der Prüfungskommission?
# ----
# Chunks:
#
# ----
# gung dieser Aufgaben eingesetzt wird.
# (2)
# 1Dem Prüfungsausschuss gehören fünf Mitglieder an, und zwar drei Mitglieder aus der Hochschullehrer-
# gruppe, ein Mitglied, das die Mitarbeitergruppe vertritt und in der Lehre tätig ist, sowie ein Mitglied der
# Studierendengruppe. 2Die Mitglieder des Prüfungsausschusses sowie deren Vertretungen werden durch
# die jeweiligen Gruppenvertretungen benannt. 3Der Vorsitz und der stellvertretende Vorsitz, über die der
#
# ----
# Prüfungsausschuss entscheidet, müssen von Mitgliedern der Hochschullehrergruppe oder habilitierten
# Mitgliedern ausgeübt werden. 4Das studentische Mitglied hat in Bewertungsfragen und bei der Entschei-
# dung über die Anerkennung von Prüfungsleistungen nur beratende Stimme. 5Die Studiendekanin oder
# der Studiendekan kann, falls sie oder er nicht als Mitglied des Prüfungsausschusses benannt wird, an
# den Sitzungen des Prüfungsausschusses mit beratender Stimme teilnehmen.
#
# ----
# gen Beisitzenden als Einzelprüfung statt. 4Wesentliche Gegenstände der Prüfungsleistung werden in
# einem Protokoll festgehalten. 5Studierende, die sich an einem späteren Prüfungstermin der gleichen
# Prüfung unterziehen wollen, sowie andere Mitglieder der Hochschule, die ein eigenes berechtigtes
# Interesse geltend machen, sind als Zuhörende bei Künstlerisch-Wissenschaftlichen Präsentationen
# zuzulassen. 6Dies erstreckt sich nicht auf die Beratung und Bekanntgabe des Prüfungsergebnisses
#
# ----
# § 5  Prüferinnen und Prüfer sowie Beisitzende
# 1Das nach § 3 zuständige Organ bestellt für die Module des Studiengangs Informatik Mitglieder der Hoch-
# schullehrergruppe der Fakultät für Elektrotechnik und Informatik der Gottfried Wilhelm Leibniz Universität
# Hannover als Prüfungsberechtigte sowie die Beisitzenden. 2Das nach § 3 zuständige Organ kann weitere
# Prüfende bestellen, sofern diese mindestens die durch die Prüfung festzustellende oder eine gleichwertige
#
# ----
# (3) 1Die Mitglieder des Prüfungsausschusses und deren Vertretungen unterliegen der Amtsverschwiegen-
# heit. 2Sofern sie nicht im öffentlichen Dienst stehen, sind sie durch die Vorsitzende oder den Vorsitzen-
# den zur Verschwiegenheit zu verpflichten.
# (4) 1Der Prüfungsausschuss ist beschlussfähig, soweit die Mehrheit der stimmberechtigten Mitglieder anwe-
# send ist. 2Beschlüsse werden mit der Mehrheit der abgegebenen gültigen Stimmen gefasst; Stimmenthal-
#
#
#
#
#
# ANTWORT DES MODELLS:
# --------------------------------------------------
# In der Prüfungskommission (Prüfungsausschuss) sind **fünf Personen**: **drei** aus der Hochschullehrergruppe, **eine** Person aus der Mitarbeitergruppe (in der Lehre tätig) und **eine** Person aus der Studierendengruppe.
